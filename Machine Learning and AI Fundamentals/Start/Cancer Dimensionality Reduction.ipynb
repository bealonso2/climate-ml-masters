# %% [markdown]
# # Cancer Dimensionality Reduction Project
#
# In this project, we will use the [Breast cancer wisconsin (diagnostic) dataset](https://scikit-learn.org/1.5/datasets/toy_dataset.html#breast-cancer-wisconsin-diagnostic-dataset) to reduce the number of features. This dataset contains 569 samples and 30 features. The features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image.
#
# In this project, we will use the following dimensionality reduction techniques to visualize a reduced number of features:
# - Principal Component Analysis (PCA)
# - t-Distributed Stochastic Neighbor Embedding (t-SNE)
#
# The required libraries will be listed in the next cell for you to install if you don't have them already.

# %%
# !pip install -q scikit-learn matplotlib

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_breast_cancer

# Load the features and target from the breast cancer dataset

# Normalize and center the data using sklearn's StandardScaler

# %% [markdown]
# ## Reflection
#
# Scaling your data is necessary before performing PCA. PCA is sensitive to the variances of the features, and scaling ensures that each feature contributes equally to the analysis. The StandardScaler standardizes the features by removing the mean and scaling to unit variance, which is a common preprocessing step before PCA.
#
# ## Instructions
#
# Let's visualize the PCA dimensionality reduction technique using the breast cancer dataset.
#
# In the next cell:
# 1. Initialize a PCA model with 2 components (for 2D visualization purposes).
# 2. Fit the PCA model to the scaled data.
# 3. Transform the scaled data using the fitted PCA model.
# 4. Visualize the transformed data using a scatter plot.

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Initialize PCA with 2 components

# Fit and transform the data using PCA

# Plot the PCA results, coloring by the target (actual diagnosis)
plt.figure(figsize=(8, 6))
plt.scatter(
    data_pca[:, 0], data_pca[:, 1], c=target, cmap="viridis", edgecolor="k", s=100
)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA of Brest Cancer Dataset")
plt.colorbar()
plt.show()

# %% [markdown]
# ## Reflection
#
# The PCA model reduces the number of features to 2, which allows us to visualize the data in a 2D space. The scatter plot shows the distribution of the data points in the reduced feature space. The data points are colored based on the target labels (malignant or benign), which helps us understand the separation between the two classes.
#
# This helps us understand the distribution of the data points in the reduced feature space and how well the PCA model captures the variance in the data (which seems to be well-separated in this case).
#
# ## Instructions
#
# Let's visualize the t-SNE dimensionality reduction technique using the breast cancer dataset.
#
# In the next cell:
# 1. Initialize a t-SNE model with 2 components (for 2D visualization purposes).
# 2. Fit the t-SNE model to the scaled data.
# 3. Transform the scaled data using the fitted t-SNE model.
# 4. Visualize the transformed data using a scatter plot.

# %%
from sklearn.manifold import TSNE

# Initialize t-SNE with 2 components

# Fit and transform the data using t-SNE

# Plot the t-SNE results, coloring by the target (actual diagnosis)
plt.figure(figsize=(8, 6))
plt.scatter(
    data_tsne[:, 0], data_tsne[:, 1], c=target, cmap="viridis", edgecolor="k", s=100
)
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.title("t-SNE of Breast Cancer Dataset")
plt.colorbar()
plt.show()

# %% [markdown]
# ## Reflection
#
# The t-SNE model is a little bit different from PCA in that it tries to preserve the local structure of the data points in the reduced feature space. This often results in better separation of the data points compared to PCA, especially in high-dimensional datasets.
#
# The t-SNE model is particularly effective for visualizing non-linear relationships in the data, which can be useful for exploring complex datasets like the breast cancer dataset.
#
# ## Final Thoughts
#
# In this project, we used PCA and t-SNE to reduce the number of features in the breast cancer dataset and visualize the data in a lower-dimensional space. Both techniques provided valuable insights into the structure of the data and the relationships between the features.
#
# PCA captures the variance in the data and provides a global view of the data distribution, while t-SNE preserves the local structure of the data and helps identify patterns that may not be apparent in the original feature space.
#
# ## Next Steps
#
# Try to apply these dimensionality reduction techniques to other datasets we come across throughout this course. Understanding how to visualize high-dimensional data in a lower-dimensional space can help us gain insights into the structure of the data and identify patterns that may not be apparent in the original feature space.
#
# Let's move on to the next project where we will take a dip into the world of deep learning and build a neural network.
